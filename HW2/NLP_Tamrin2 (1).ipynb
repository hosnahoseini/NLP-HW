# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive//MyDrive/NLP_Spring403/Tamrin2
# Out:
# /content/drive/.shortcut-targets-by-id/1dwarz0mo_-fmqYTonUV2rQvpTcng3geb/NLP_Spring403/Tamrin2

# %% [markdown]
# #Import

# %%
import re
from re import sub
import itertools

# %% [markdown]
# # Char

# %%
one_char = {
 'b': ['ب'],
 'd': ['د'],
 'f': ['ف'],
 'g': ['گ'],
 'k': ['ک'],
 'l': ['ل'],
 'm': ['م'],
 'n': ['ن'],
 'p': ['پ'],
 'r': ['ر'],
 "u'": ['وئ'],
 'v': ['و'],
 'w': ['و'],
 'x': ['کس'],
 'y': ['ی'],

}

# %%
two_char = {
    "ch": ["چ"],
    "gh": ["غ", "ق"],
    "ei": ["ی" , "ئی", "یی", "عی"],
    "sh": ["ش"],
    "zh": ["ژ"],
    "ck": ["ک"],
    "x": ["کس"],
    "kh": ["خ"],
    "a'": ['','ع', 'ئ', 'اع', 'اء'],

  }

# %%
multiple_char = {
 "A'": ['اع', 'اء'],
 'a': ['', 'ا', 'اع', 'ع'],
 "a'": ['','ع', 'ئ', 'اع', 'اء'],
 'e': ['ع', 'ه', ''],
 "e'": ['ع', 'ئ'],
 'ei': ['ئی', 'یی', 'عی'],
 "'": ['ء', 'عa', '', 'ع', 'ا', 'اع', 'أ', 'ؤ', 'ؤا', 'ئا', 'ئ'],
 "'A": ['ئا', 'عا'],
 "'a": ['ئا', 'عا'],
 "'e": ['ع', 'ء'],
 "'i": ['ئی', 'عی'],
 "'o": ['عو', 'ئو'],
 "'u": ['ئو', 'عو'],
 'gh': ['ق', 'غ'],
 'h': ['ه', 'ح'],
 'i': ['ی', 'یع'],
 "i'": ['یع', 'یئ'],
 'j': ['ج', 'ژ'],
 'o': ['و', 'وع', ''],
 "o'": ['ع', 'ئ', 'وع'],
 'q': ['ق', 'غ'],
 's': ['س', 'ث', 'ص'],
 't': ['ت', 'ط'],
 'u': ['و', 'وع'],
 'z': ['ز', 'ذ', 'ض', 'ظ'],
 '@':['خ', 'خوا','خا'],
 }

# %% [markdown]
# # Numbers

# %%
numbers = {'1' : '۱', '2' : '۲', '3' : '۳', '4' : '۴', '5' : '۵', '6' : '۶', '7' : '۷', '8' : '۸', '9' : '۹', '0' : '۰' }

# %% [markdown]
# # Special Words

# %%
special_words = {
 'khahar' : ['خواهر'],
 'khahesh': ['خواهش'],
 'khab': ['خواب'],
 'khand': ['حواند'],
 'khandan': ['خواندن'],
 'acid': ['اسید'],
 'action': ['اکشن'],
 'africa': ['آفریقا'],
 'alem': ['عالم'],
 'allah': ['الله'],
 'alpha': ['آلفا'],
 'ambulance': ['آمبولانس'],
 'amdan': ['عمداً'],
 'america': ['آمریکا'],
 'apple': ['اپل'],
 'aquarium': ['آکواریوم'],
 'archive': ['آرشیو'],
 'arrange': ['ارنج'],
 'ashegh': ['عاشق'],
 'asheq': ['عاشق'],
 'ashghal': ['آشغال'],
 'ashqal': ['آشغال'],
 'attari': ['عطاری'],
 'automatic': ['اتوماتیک'],
 'avalan': ['اولاً'],
 'avvalan': ['اولاً'],
 'ayate': ['آیات'],
 'ayatollah': ['آیت\u200cالله'],
 'ayat': ['آیات'],
 'aziztarinam': ['عزیزترینم'],
 'baba': ['بابا'],
 'barooni': ['بارونی'],
 'baroon': ['بارون'],
 'basic': ['بیسیک'],
 'bbc': ['بی\u200cبی\u200cسی'],
 'beat': ['بیت'],
 'bekaram': ['بکارم'],
 'bekarim': ['بکاریم'],
 'bellucci': ['بلوچی'],
 'beshe': ['بشه'],
 'bia': ['بیا'],
 'bighararam': ['بیقرارم'],
 'blog': ['بلاگ'],
 'bmw': ['بی\u200cام\u200cو'],
 'bot': ['بات'],
 'burder': ['برگر'],
 'burger': ['برگر'],
 'byte': ['بایت'],
 'cable': ['کابل'],
 'cache': ['کش'],
 'cafe': ['کافه'],
 'cake': ['کیک'],
 'campaign': ['کمپین'],
 'cam': ['کم'],
 'canada': ['کانادا'],
 'captain': ['کاپیتان'],
 'card': ['کارد'],
 'car': ['کار'],
 'case': ['کیس'],
 'cat': ['کت'],
 'cd': ['سی\u200cدی'],
 'celebrity': ['سلبریتی'],
 'centimeter': ['سانتی\u200cمتر'],
 'check': ['چک'],
 'christmas': ['کریسمس'],
 'cigar': ['سیگار'],
 'cinema': ['سینما'],
 'class': ['کلاس'],
 'claud': ['کلاود'],
 'cloud': ['کلاود'],
 'coca': ['کوکا'],
 'coffeeshop': ['کافی\u200cشاپ'],
 'coffee': ['کافی'],
 'computer': ['کامپیوتر'],
 'console': ['کنسول'],
 'cooler': ['کولر'],
 'course': ['کورس'],
 'cover': ['کاور'],
 'cpu': ['سی\u200cپی\u200cیو'],
 'crash': ['کرش'],
 'crush': ['کراش'],
 'daghighan': ['دقیقاً'],
 'dana': ['دانا'],
 'daqiqan': ['دقیقاً'],
 'daram': ['دارم'],
 'darde': ['درد'],
 'dard': ['درد'],
 'dareh': ['داره'],
 'decor': ['دکور'],
 'digital': ['دیجیتال'],
 'doa': ['دعا'],
 'doctora': ['دکترا'],
 'doctor': ['دکتر'],
 'dom': ['دم'],
 'dor': ['دور'],
 'dvd': ['دی\u200cوی\u200cدی'],
 'echo': ['اکو'],
 'eco': ['اکو'],
 'ejalatan': ['اجالتاً'],
 'elahi': ['الهی'],
 'esrar': ['اصرار'],
 'esteda': ['استدعا'],
 'etelaat': ['اطلاعات'],
 'ettelaat': ['اطلاعات'],
 'euro': ['یورو'],
 'excel': ['اکسل'],
 'face': ['فیس'],
 'fardaye': ['فردای'],
 'fasele': ['فاصله'],
 'fax': ['فاکس'],
 'fbi': ['اف\u200cبی\u200cآی'],
 'ferdowsi': ['فردوسی'],
 'ferdows': ['فردوس'],
 'foran': ['فوراً'],
 'france': ['فرانسه'],
 'francisco': ['فرانسیسکو'],
 'friend': ['فرند'],
 'gamer': ['گیمر'],
 'game': ['گیم'],
 'gereye': ['گره'],
 'ghalb': ['قلب'],
 'gham': ['غم'],
 'ghatan': ['قطعاً'],
 'ghatel': ['قاتل'],
 'ghayeb': ['غایب'],
 'gholam': ['غلام'],
 'ghuran': ['قرآن'],
 'gigabyte': ['گیگابایت'],
 'gipsy': ['جیپسی'],
 'github': ['گیتهاب'],
 'good': ['گود'],
 'google': ['گوگل'],
 'gpu': ['جی\u200cپی\u200cیو'],
 'grade': ['گرید'],
 'green': ['گرین'],
 'group': ['گروپ'],
 'guitar': ['گیتار'],
 'hacker': ['هکر'],
 'hafez': ['حافظ'],
 'haghighatan': ['حقیقتاً'],
 'hamburger': ['همبرگر'],
 'hame': ['همه'],
 'haqiqatan': ['حقیقتاً'],
 'hasabe': ['حسب'],
 'hasab': ['حسب'],
 'hatman': ['حتماً'],
 'hatm': ['حتم'],
 'havalie': ['حوالی'],
 'headphones': ['هدفون'],
 'headphone': ['هدفون'],
 'headset': ['هدست'],
 'hi': ['های'],
 'holiday': ['هالیدی'],
 #'hub': ['هاب'],
 'hybrid': ['هیبرید'],
 'hyper': ['هایپر'],
 'ice': ['آیس'],
 'image': ['ایمیج'],
 'ios': ['آی\u200cاو\u200cاس'],
 'iphone': ['آیفون'],
 'isa': ['عیسی'],
 'israel': ['اسرائیل'],
 'istanbul': ['استانبول'],
 'jadidan': ['جدیداً'],
 'javanan': ['جوانان'],
 'javan': ['جوان'],
 'jesaaratan': ['جسارتاً'],
 'jesaratan': ['جسارتاً'],
 'john': ['جان'],
 'kamal': ['کمال'],
 'kamelan': ['کاملاً'],
 'kashef': ['کاشف'],
 'kashtand': ['کاشتند'],
 'keyboard': ['کیبرد'],
 'khamesan': ['خامساً'],
 'khaneye': ['خانه'],
 'khiali': ['خیالی'],
 'khoda': ['خدا'],
 'kilobyte': ['کیلوبایت'],
 'kiss': ['کیس'],
 'kollan': ['کلاً'],
 'kon': ['کن'],
 'kooche': ['کوچه'],
 'kuche': ['کوچه'],
 'like': ['لایک'],
 'linux': ['لینوکس'],
 'live': ['لایو'],
 'load': ['لود'],
 'london': ['لندن'],
 'macbook': ['مک\u200cبوک'],
 'machine': ['ماشین'],
 'mac': ['مک'],
 'mage': ['مگه'],
 'maman': ['مامان'],
 'mamoor': ['مأمور'],
 'mamour': ['مأمور'],
 'mamur': ['مأمور'],
 'maree': ['مرئی'],
 'meena': ['مینا'],
 'megabyte': ['مگابایت'],
 'merci': ['مرسی'],
 'microscope': ['میکروسکوپ'],
 'microsoft': ['مایکروسافت'],
 'micro': ['میکرو'],
 'mobile': ['موبایل'],
 'moosa': ['موسی'],
 'mother': ['مادر'],
 'music': ['موزیک'],
 'naghes': ['ناقص'],
 'naghez': ['ناقض'],
 'naqes': ['ناقص'],
 'naqez': ['ناقض'],
 'na': ['نه'],
 'nesbatan': ['نسبتاً'],
 'nostalgia': ['نوستالژی'],
 'official': ['آفیشال'],
 'offline': ['آفلاین'],
 'off': ['آف'],
 'okay': ['اوکی'],
 'ok': ['اوکی'],
 'online': ['آنلاین'],
 'on': ['آن'],
 'option': ['آپشن'],
 'order': ['اوردر'],
 'original': ['اورجینال'],
 'oscar': ['اسکار'],
 'o': ['و'],
 'pc': ['پی\u200cسی'],
 'performance': ['پرفورمنس'],
 'pizza': ['پیتزا'],
 'police': ['پلیس'],
 'polytechnic': ['پلی\u200cتکنیک'],
 'powerpoint': ['پاورپوینت'],
 'puzzle': ['پازل'],
 'pv': ['پی\u200cوی'],
 'python': ['پایتون'],
 'qatel': ['قاتل'],
 'qayeb': ['غایب'],
 'quran': ['قرآن'],
 'rank': ['رنک'],
 'record': ['رکورد'],
 'sabet': ['ثابت'],
 'salame': ['سلام'],
 'salam': ['سلام'],
 'salesan': ['ثالثاً'],
 'sanian': ['ثانیاً'],
 'sareean': ['سریعاً'],
 'sarian': ['سریعاً'],
 'screenshot': ['اسکرین\u200cشات'],
 'snapp': ['اسنپ'],
 'snap': ['اسنپ'],
 'soal': ['سؤال'],
 'sos': ['سس'],
 'source': ['سورس'],
 'speaker': ['اسپیکر'],
 'standard': ['استاندارد'],
 'steel': ['استیل'],
 'support': ['ساپورت'],
 'tadrijan': ['تدریجاً'],
 'taghriban': ['تقریباً'],
 'tahghighan': ['تحقیقاً'],
 'tahqian': ['تحقیقاً'],
 'taqriban': ['تقریباً'],
 'taxi': ['تاکسی'],
 'telephone': ['تلفن'],
 'telephony': ['تلفنی'],
 'touch': ['تاچ'],
 'turkey': ['ترکیه'],
 'type': ['تایپ'],
 'up': ['آپ'],
 'usb': ['یو\u200cاس\u200cبی'],
 'user': ['یوزر'],
 "vaghe'an": ['واقعاً'],
 'vaghean': ['واقعاً'],
 'vala': ['والا'],
 "vaqe'an": ['واقعاً'],
 'vaqean': ['واقعاً'],
 'vay': ['وای'],
 'video': ['ویدیو'],
 'voice': ['وویس'],
 'vpn': ['وی\u200cپی\u200cان'],
 'web': ['وب'],
 'word': ['ورد'],
 'ye': ['یه'],
 'youtube': ['یوتوب'],
 'you': ['یو'],
 'zaheran': ['ظاهراً'],
 'mitabad':['میتابد'],
}

# %% [markdown]
# # Preprocessing

# %%
def preprocess_text(text):
    # حذف فضای اضافه از ابتدا و انتهای متن
    text = text.strip()
    # تبدیل فاصله‌های متعدد به یک فاصله
    text = re.sub(r'\s+', ' ', text)
    # تبدیل متن به حروف کوچک
    return text.lower()

# %%
text = " salam Chetori?"
preprocess_text(text)
# Out:
# 'salam chetori?'

# %% [markdown]
# ## Postprocess

# %%
def load_dictionary(file_path):
    dict = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        g = f.readlines()
        for Wrds in g:
            wrd = Wrds.split(' ')
            dict[wrd[0].strip()] = sub('\n', '', wrd[1].strip())
    return dict

# %%
normalize_data_path = "normalize.txt"
dic = load_dictionary(normalize_data_path)

# %%
# درست کردن نیم فاصله ها
def space_correction(text):
    a00 = r'^(بی|می|نمی)( )'
    b00 = r'\1‌'
    c00 = sub(a00, b00, text)
    a0 = r'( )(می|نمی|بی)( )'
    b0 = r'\1\2‌'
    c0 = sub(a0, b0, c00)
    a1 = r'( )(هایی|ها|های|ایی|هایم|هایت|هایش|هایمان|هایتان|هایشان|ات|ان|ین' \
            r'|انی|بان|ام|ای|یم|ید|اید|اند|بودم|بودی|بود|بودیم|بودید|بودند|ست)( )'
    b1 = r'‌\2\3'
    c1 = sub(a1, b1, c0)
    a2 = r'( )(شده|نشده)( )'
    b2 = r'‌\2‌'
    c2 = sub(a2, b2, c1)
    a3 = r'( )(طلبان|طلب|گرایی|گرایان|شناس|شناسی|گذاری|گذار|گذاران|شناسان|گیری|پذیری|بندی|آوری|سازی|' \
            r'بندی|کننده|کنندگان|گیری|پرداز|پردازی|پردازان|آمیز|سنجی|ریزی|داری|دهنده|آمیز|پذیری' \
            r'|پذیر|پذیران|گر|ریز|ریزی|رسانی|یاب|یابی|گانه|گانه‌ای|انگاری|گا|بند|رسانی|دهندگان|دار)( )'
    b3 = r'‌\2\3'
    c3 = sub(a3, b3, c2)
    return c3

# %%
text = "می آیم"
space_correction(text)
# Out:
# 'می\u200cآیم'

# %%
def space_correction_2(text):
    out_sentences = ''
    for wrd in text.split(' '):
        try:
            out_sentences = out_sentences + ' ' + dic[wrd]
        except KeyError:
            out_sentences = out_sentences + ' ' + wrd
    return out_sentences

# %%
text = "حاشیهنشینی"
space_correction_2(text)
# Out:
# ' حاشیه\u200cنشینی'

# %% [markdown]
# # Conversion

# %%
import urllib.request

def download_file(url, filename):
    try:
        urllib.request.urlretrieve(url, filename)
        print(f"File downloaded successfully as '{filename}'")
    except Exception as e:
        print(f"Error downloading file: {e}")

# %%
def load_frequency_file(filename):
    frequencies = {}
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            # print(line)
            if line[0] != "#":
              word, frequency = line.strip().split('\t')
              frequencies[word] = int(frequency)
    return frequencies

# Load frequencies from file
frequencies = load_frequency_file("persian-wikipedia.txt")

# %%
import urllib.request

def download_file(url, filename):
    try:
        urllib.request.urlretrieve(url, filename)
        print(f"File downloaded successfully as '{filename}'")
    except Exception as e:
        print(f"Error downloading file: {e}")

url = "https://raw.githubusercontent.com/behnam/persian-words-frequency/master/persian-wikipedia.txt"
filename = "persian-wikipedia.txt"

download_file(url, filename)
frequencies = load_frequency_file("persian-wikipedia.txt")
# Out:
# File downloaded successfully as 'persian-wikipedia.txt'

# %%
frequencies['میتابد'] = 1

# %%
def choose_highest_frequency_combination(combinations, frequencies):
    max_frequency = 0
    best_combination = None
    for combination in combinations:
        frequency = frequencies.get(combination, 0)
        if frequency > max_frequency:
            max_frequency = frequency
            best_combination = combination
    best_combination
    return best_combination

# %%
def split_finglish_persian(word):
    # Regular expression to match sequences of Latin or Persian characters
    latin_pattern = re.compile(r'[a-zA-Z]+')
    persian_pattern = re.compile(r'[\u0600-\u06FF]+')
    # Find all matches of Latin and Persian sequences
    parts = []
    while word:
        latin_match = latin_pattern.match(word)
        persian_match = persian_pattern.match(word)

        if latin_match:
            parts.append(latin_match.group(0))
            word = word[latin_match.end():]
        elif persian_match:
            parts.append(persian_match.group(0))
            word = word[persian_match.end():]

        else:
            # In case of any non-matching characters (optional handling)
            parts.append(word[0])
            word = word[1:]

    return parts

# %%
kha_pattern = {
     'kha':['@'],
}

# %%
def convert_finglish_to_persian_word(word, frequencies):

    for key in special_words.keys():
        word = re.sub(key, [key][0], word)
    if word in numbers:
      return numbers[word]

    for key in kha_pattern.keys():
        word = re.sub(key, kha_pattern[key][0], word)

    for key in two_char.keys():
        word = re.sub(key, two_char[key][0], word)


    for key in one_char.keys():
        word = re.sub(key, one_char[key][0], word)


    ########## handeling multiple forms
    parts = split_finglish_persian(word)
    latin_pattern = re.compile(r'[a-zA-Z@]+')

    all_comb = []
    vars = {}
    for part in parts:
        latin_match = latin_pattern.match(part)
        if latin_match:
            for key in multiple_char.keys():
                if key in part:
                   vars[key] = multiple_char[key]

            pattern = "|".join(re.escape(key) for key in vars.keys())
            regex = re.compile(pattern)
            found_keys = regex.findall(part)
            for key in found_keys:
                all_comb.append(multiple_char[key])
        else:
            all_comb.append([part])
    alternatives = [''.join(comb) for comb in itertools.product(*all_comb)]
    print(alternatives)
    choosed_persian_word = choose_highest_frequency_combination(alternatives, frequencies)

    return choosed_persian_word

def convert_finglish_to_persian(text, frequencies):
  text = preprocess_text(text).split(" ")
  res = ""
  for word in text:
    word = convert_finglish_to_persian_word(word, frequencies)
    res += word + " "

  return res

# %% [markdown]
# # Our Samples

# %%
# Example usage:
finglish_text = "khahar"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'خواهر '

# %%
# Example usage:
finglish_text = "tahmures"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'طهمورث '

# %%
# Example usage:
finglish_text = "khabam miad"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'خوابم مید '

# %%
# Example usage:
finglish_text = "hushe masnoi"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'هوش مصنوعی '

# %%
# Example usage:
finglish_text = "khaharam khastan tavanestan ast"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'خواهرم خواستن توانستن است '

# %% [markdown]
# # Samples from TA

# %%
# Example usage:
finglish_text = "cheraghe khane ra roshan konid"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'چراغ خانه را روشن کنید '

# %%
# Example usage:
finglish_text = "hozoore mihmanan gerami ra kheir maqdam arz mikonim "
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# ['هوزوورع', 'هوزووره', 'هوزوور', 'هوزووعرع', 'هوزووعره', 'هوزووعر', 'هوزورع', 'هوزوره', 'هوزور', 'هوزوعورع', 'هوزوعوره', 'هوزوعور', 'هوزوعوعرع', 'هوزوعوعره', 'هوزوعوعر', 'هوزوعرع', 'هوزوعره', 'هوزوعر', 'هوزورع', 'هوزوره', 'هوزور', 'هوزوعرع', 'هوزوعره', 'هوزوعر', 'هوزرع', 'هوزره', 'هوزر', 'هوذوورع', 'هوذووره', 'هوذوور', 'هوذووعرع', 'هوذووعره', 'هوذووعر', 'هوذورع', 'هوذوره', 'هوذور', 'هوذوعورع', 'هوذوعوره', 'هوذوعور', 'هوذوعوعرع', 'هوذوعوعره', 'هوذوعوعر', 'هوذوعرع', 'هوذوعره', 'هوذوعر', 'هوذورع', 'هوذوره', 'هوذور', 'هوذوعرع', 'هوذوعره', 'هوذوعر', 'هوذرع', 'هوذره', 'هوذر', 'هوضوورع', 'هوضووره', 'هوضوور', 'هوضووعرع', 'هوضووعره', 'هوضووعر', 'هوضورع', 'هوضوره', 'هوضور', 'هوضوعورع', 'هوضوعوره', 'هوضوعور', 'هوضوعوعرع', 'هوضوعوعره', 'هوضوعوعر', 'هوضوعرع', 'هوضوعره', 'هوضوعر', 'هوضورع', 'هوضوره', 'هوضور', 'هوضوعرع', 'هوضوعره', 'هوضوعر', 'هوضرع', 'هوضره', 'هوضر', 'هوظوورع', 'هوظووره', 'هوظوور', 'هوظووعرع', 'هوظووعره', 'هوظووعر', 'هوظورع', 'هوظوره', 'هوظور', 'هوظوعورع', 'هوظوعوره', 'هوظوعور', 'ه
# ...

# %%
# Example usage:
finglish_text = "khorshid souzan mitabad"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# 'خورشید سوزان میتابد '

# %%
# Example usage:
finglish_text = "ketab khani moa'ser ast"
persian_text = convert_finglish_to_persian(finglish_text, frequencies)
persian_text
# Out:
# ['کعتب', 'کعتاب', 'کعتاعب', 'کعتعب', 'کعطب', 'کعطاب', 'کعطاعب', 'کعطعب', 'کهتب', 'کهتاب', 'کهتاعب', 'کهتعب', 'کهطب', 'کهطاب', 'کهطاعب', 'کهطعب', 'کتب', 'کتاب', 'کتاعب', 'کتعب', 'کطب', 'کطاب', 'کطاعب', 'کطعب']
# ['خنی', 'خنیع', 'خوانی', 'خوانیع', 'خانی', 'خانیع']
# ['موسعر', 'موسهر', 'موسر', 'موثعر', 'موثهر', 'موثر', 'موصعر', 'موصهر', 'موصر', 'موعسعر', 'موعسهر', 'موعسر', 'موعثعر', 'موعثهر', 'موعثر', 'موعصعر', 'موعصهر', 'موعصر', 'مسعر', 'مسهر', 'مسر', 'مثعر', 'مثهر', 'مثر', 'مصعر', 'مصهر', 'مصر']
# ['ست', 'سط', 'ثت', 'ثط', 'صت', 'صط', 'است', 'اسط', 'اثت', 'اثط', 'اصت', 'اصط', 'اعست', 'اعسط', 'اعثت', 'اعثط', 'اعصت', 'اعصط', 'عست', 'عسط', 'عثت', 'عثط', 'عصت', 'عصط']
# 'کتاب خانی مصر است '

# %%
frequencies['موثر']
# Out:
# 979

# %%
frequencies['مصر']
# Out:
# 4402

# %%
frequencies['گرامی']
# Out:
# 250

# %%
frequencies['گرمی']
# Out:
# 1144
